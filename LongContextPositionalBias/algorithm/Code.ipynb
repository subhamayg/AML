# %% [markdown]
# **Identifying Positional Bias in Long-Context Language Models**
#
# ## Connect with OLLAMA

# %%
# Install ollama
# !curl -fsSL https://ollama.com/install.sh | sh   # linux / mac
# !irm https://ollama.com/install.ps1 | iex        # windows

# then download these models
# !ollama pull tinyllama
# !ollama pull llama3.2:1b
# !ollama pull llama3.2:3b
# !ollama pull llama3:8b
# Out:
# /bin/bash: line 1: ollama: command not found

# %%
import requests

# ensure ollama service is running, else manually start using 'ollama serve' 
OLLAMA_URL = "http://localhost:11434/api/generate"
TARGET_MODEL = "tinyllama"

payload = {
    "model": TARGET_MODEL,
    "prompt": "What is 2 + 2? Answer only the number.",
    "stream": False
}

response = requests.post(OLLAMA_URL, json=payload)
print(response.json()["response"])
# Out:
# The answer to the question "what is 2 + 2?" is: 4.

# %% [markdown]
# ## Synthetic Dataset Generator for Positional Bias Experiment (0-shot prompting)
#
# We construct a synthetic dataset to evaluate positional bias in large language models (LLMs) by measuring their ability to retrieve relevant information from different locations within a context. Each sample consists of a set of textual facts describing multiple fictional projects, among which exactly one fact contains the correct answer.
#
# For each sample, a target project is randomly selected from a predefined pool of project names, and a corresponding five-digit identifier code is generated as the ground truth. The relevant evidence sentence is constructed in the form: “The identifier code for Project X is Y.” This sentence is embedded within a larger context composed of distractor facts.
#
# Distractor sentences follow a similar syntactic structure but vary along two dimensions: project names and key types. Project names are drawn either from a standard set (e.g., Aurora, Orion, Vega) or from a confusable set containing closely related variants (e.g., AuroraX, Aurora-Prime). Similarly, distractor keys include both clearly distinct attributes (e.g., access code, backup code, server pin) and semantically similar variants (e.g., identifier token, identification code, reference code). Numerical values for distractors are randomly generated, with constraints ensuring that the correct answer is unique and not duplicated elsewhere in the context.
#
# To increase task difficulty, we introduce controlled variation across three difficulty levels: easy, medium, and hard. In the easy setting, distractors use distinct project names and keys. In the medium setting, confusable project names are introduced. In the hard setting, both confusable project names and semantically similar keys are used, and distractors may also include multiple references to the target project with incorrect attributes. This design forces the model to jointly reason over both the project identity and the attribute type, rather than relying on simple keyword matching.
#
# We systematically vary two primary independent variables: context length and evidence position. Context length has three levels: short (20 distractors), medium (60 distractors), and long (120 distractors). Evidence position has three levels: beginning, middle, and end, determined by where the correct sentence is inserted within the context. This enables analysis of primacy and recency effects as well as degradation in middle-context retrieval.
#
# Each sample is formatted as a zero-shot question-answering prompt, where the model is asked to identify the identifier code for the target project and instructed to return only the numeric value. The dataset is generated in a fully factorial manner across difficulty levels, context lengths, and evidence positions. By default, 10 samples are generated per condition, yielding a total of 2160 samples (3 difficulties × 3 context lengths × 3 positions × 80 samples per condition). The dataset is shuffled prior to evaluation to eliminate ordering effects.
#
# Model performance is evaluated using exact-match accuracy, computed by extracting the first five-digit number from the model output and comparing it with the ground truth. This controlled experimental setup enables systematic analysis of positional bias, including primacy effects, recency effects, and performance degradation in mid-context regions, while also examining how these effects interact with task difficulty and model capacity.

# %%
"""
Synthetic dataset generator for a positional-bias experiment.

The dataset tests whether LLM retrieval accuracy changes when the relevant
evidence appears at the beginning, middle, or end of a context.

The generator also varies:
    1. context length
    2. task difficulty
    3. evidence position

Output:
    positional_bias_dataset.jsonl
"""

from __future__ import annotations

import json
import random
from dataclasses import asdict, dataclass
from pathlib import Path
from typing import Literal


# ---------------------------------------------------------------------
# Type aliases
# ---------------------------------------------------------------------

Position = Literal["beginning", "middle", "end"]
ContextLength = Literal["short", "medium", "long"]
Difficulty = Literal["easy", "medium", "hard"]


# ---------------------------------------------------------------------
# Experiment constants
# ---------------------------------------------------------------------

POSITIONS: tuple[Position, ...] = ("beginning", "middle", "end")

CONTEXT_CONFIGS: dict[ContextLength, int] = {
    "short": 20,
    "medium": 60,
    "long": 120,
}

EASY_PROJECT_NAMES = [
    "Aurora", "Orion", "Lyra", "Vega", "Nimbus", "Atlas",
    "Helios", "Nova", "Echo", "Titan", "Solace", "Zephyr",
]

CONFUSING_PROJECT_NAMES = [
    "Aurora", "AuroraX", "Aurora-Prime",
    "Orion", "OrionX", "Orion-Prime",
    "Lyra", "LyraX", "Lyra-Prime",
    "Vega", "VegaX", "Vega-Prime",
]

EASY_DISTRACTOR_KEYS = [
    "access code",
    "backup code",
    "archive key",
    "server pin",
]

CONFUSING_DISTRACTOR_KEYS = [
    "identifier token",
    "identification code",
    "internal code",
    "reference code",
    "identifier code",
    "access code",
    "backup code",
    "archive key",
    "server pin",
]

QUESTION_TEMPLATES: dict[Difficulty, str] = {
    "easy": "What is the identifier code for Project {project}?",
    "medium": "Find the identifier code assigned to Project {project}.",
    "hard": "Which five-digit number is the identifier code associated with Project {project}?",
}


@dataclass(frozen=True)
class DifficultyConfig:
    """Controls how challenging each task variant is."""

    use_CONFUSING_projects: bool
    use_CONFUSING_keys: bool


DIFFICULTY_CONFIGS: dict[Difficulty, DifficultyConfig] = {
    "easy": DifficultyConfig(
        use_CONFUSING_projects=False,
        use_CONFUSING_keys=False,
    ),
    "medium": DifficultyConfig(
        use_CONFUSING_projects=True,
        use_CONFUSING_keys=False,
    ),
    "hard": DifficultyConfig(
        use_CONFUSING_projects=True,
        use_CONFUSING_keys=True,
    ),
}


# ---------------------------------------------------------------------
# Data containers
# ---------------------------------------------------------------------

@dataclass(frozen=True)
class DatasetConfig:
    """Configuration for the full dataset generation run."""

    samples_per_condition: int = 80
    random_seed: int = 42
    output_path: Path = Path("positional_bias_dataset.jsonl")
    shuffle: bool = True


@dataclass(frozen=True)
class Sample:
    """One synthetic retrieval example."""

    sample_id: int
    difficulty: Difficulty
    context_length: ContextLength
    num_distractors: int
    evidence_position: Position
    target_project: str
    gold_answer: str
    evidence_sentence: str
    prompt: str


class PositionalBiasDatasetGenerator:
    """Generate controlled prompts for studying positional bias in LLMs."""

    def __init__(self, config: DatasetConfig) -> None:
        self.config = config
        self.rng = random.Random(config.random_seed)

    def generate_code(self) -> str:
        """Generate a five-digit numeric label."""
        return str(self.rng.randint(10000, 99999))

    @staticmethod
    def get_project_pool(difficulty: Difficulty) -> list[str]:
        """Select project names based on task difficulty."""
        config = DIFFICULTY_CONFIGS[difficulty]
        return (
            CONFUSING_PROJECT_NAMES
            if config.use_CONFUSING_projects
            else EASY_PROJECT_NAMES
        )

    @staticmethod
    def get_distractor_keys(difficulty: Difficulty) -> list[str]:
        """Select distractor key types based on task difficulty."""
        config = DIFFICULTY_CONFIGS[difficulty]
        return (
            CONFUSING_DISTRACTOR_KEYS
            if config.use_CONFUSING_keys
            else EASY_DISTRACTOR_KEYS
        )

    def make_distractor_fact(
        self,
        target_project: str,
        gold_answer: str,
        project_names: list[str],
        distractor_keys: list[str],
        allow_same_project: bool,
    ) -> str:
        """Create a non-answer fact."""

        while True:
            project = self.rng.choice(project_names)
            key = self.rng.choice(distractor_keys)
            value = self.generate_code()

            # No duplicate correct answers
            if value == gold_answer:
                continue

            # Control difficulty
            if not allow_same_project and project == target_project:
                continue

            return f"The {key} for Project {project} is {value}."

    @staticmethod
    def insert_evidence(
        distractors: list[str],
        evidence: str,
        position: Position,
    ) -> list[str]:
        """
        Insert the correct evidence at a controlled position.

        This is the main experimental manipulation.
        """
        if position == "beginning":
            return [evidence, *distractors]

        if position == "middle":
            middle_index = len(distractors) // 2
            return [
                *distractors[:middle_index],
                evidence,
                *distractors[middle_index:],
            ]

        if position == "end":
            return [*distractors, evidence]

        raise ValueError(f"Unsupported evidence position: {position}")

    @staticmethod
    def build_prompt(
        context_facts: list[str],
        target_project: str,
        difficulty: Difficulty,
    ) -> str:
        """Build the final model prompt."""
        context = "\n".join(context_facts)
        question = QUESTION_TEMPLATES[difficulty].format(project=target_project)

        return f"""This is a synthetic benchmark. Use the context to answer the question. Return only the final number.

Context:
{context}

Question:
{question}

Answer:"""

    def generate_sample(
        self,
        sample_id: int,
        difficulty: Difficulty,
        context_length: ContextLength,
        evidence_position: Position,
    ) -> Sample:
        """Generate one controlled synthetic retrieval sample."""
        project_names = self.get_project_pool(difficulty)
        distractor_keys = self.get_distractor_keys(difficulty)

        target_project = self.rng.choice(project_names)
        gold_answer = self.generate_code()

        evidence_sentence = (
            f"The identifier code for Project {target_project} is {gold_answer}."
        )

        num_distractors = CONTEXT_CONFIGS[context_length]

        distractors = [
            self.make_distractor_fact(
                target_project=target_project,
                gold_answer=gold_answer,
                project_names=project_names,
                distractor_keys=distractor_keys,
                allow_same_project = difficulty in ["hard"],
            )
            for _ in range(num_distractors)
        ]

        context_facts = self.insert_evidence(
            distractors=distractors,
            evidence=evidence_sentence,
            position=evidence_position,
        )

        prompt = self.build_prompt(
            context_facts=context_facts,
            target_project=target_project,
            difficulty=difficulty,
        )

        return Sample(
            sample_id=sample_id,
            difficulty=difficulty,
            context_length=context_length,
            num_distractors=num_distractors,
            evidence_position=evidence_position,
            target_project=target_project,
            gold_answer=gold_answer,
            evidence_sentence=evidence_sentence,
            prompt=prompt,
        )

    def generate_dataset(self) -> list[Sample]:
        """
        Generate a balanced dataset.

        Total samples =
            difficulties × context lengths × positions × samples_per_condition
        """
        dataset: list[Sample] = []

        for difficulty in DIFFICULTY_CONFIGS:
            for context_length in CONTEXT_CONFIGS:
                for evidence_position in POSITIONS:
                    for _ in range(self.config.samples_per_condition):
                        dataset.append(
                            self.generate_sample(
                                sample_id=len(dataset),
                                difficulty=difficulty,
                                context_length=context_length,
                                evidence_position=evidence_position,
                            )
                        )

        if self.config.shuffle:
            self.rng.shuffle(dataset)

        return dataset

    @staticmethod
    def save_jsonl(samples: list[Sample], output_path: Path) -> None:
        """Save generated samples as JSONL."""
        with output_path.open("w", encoding="utf-8") as file:
            for sample in samples:
                file.write(json.dumps(asdict(sample), ensure_ascii=False) + "\n")

        print(f"Saved {len(samples)} samples to {output_path}")


def main() -> None:
    """Generate and save the positional-bias dataset."""
    config = DatasetConfig()
    generator = PositionalBiasDatasetGenerator(config)

    dataset = generator.generate_dataset()
    generator.save_jsonl(dataset, config.output_path)


if __name__ == "__main__":
    main()
# Out:
# Saved 1080 samples to positional_bias_dataset.jsonl

# %% [markdown]
# ## Model Evaluation and Experimental Setup
#
# To evaluate positional bias across models of varying capacity, we conduct controlled experiments using multiple instruction-tuned large language models accessed via a local inference framework. Specifically, we evaluate TinyLlama, Llama 3.2 1B, Llama 3.2 3B, and Llama 3 8b representing a spectrum of model capacities from very small to moderately sized models. TinyLlama serves as an extreme low-capacity baseline, enabling analysis of failure modes and instability in retrieval tasks, while the LLaMA 3.2/3 models provide progressively stronger instruction-following capabilities.
#
# All experiments are conducted using a zero-shot prompting setup. Each sample from the synthetic dataset is passed directly to the model without any additional examples or fine-tuning. To ensure consistent output formatting across models, the original prompt is augmented with an explicit instruction requiring the model to return exactly one five-digit numeric value. This constraint standardises responses and enables reliable evaluation.
#
# Model inference is performed through a local API endpoint, where each prompt is processed independently. Decoding is configured to be deterministic, with temperature set to zero and nucleus sampling disabled (top-p = 1), ensuring reproducibility and eliminating stochastic variation in outputs. A fixed maximum token generation limit is used to constrain output length.
#
# For each dataset sample, the model output is post-processed using a regular expression to extract the first five-digit number. This extracted value is compared against the ground truth identifier code using an exact-match criterion. A prediction is considered correct only if the extracted number exactly matches the ground truth. Outputs that do not contain a valid five-digit number are treated as incorrect predictions. Additionally, failed requests or inference errors are recorded to ensure robustness in evaluation.
#
# Evaluation is performed across all combinations of difficulty level, context length, and evidence position defined in the dataset. Each sample is evaluated independently for each model, resulting in a fully crossed experimental design. For computational efficiency during development, experiments may be conducted on a subset of the dataset; however, final results are reported on the complete dataset.
#
# Results are aggregated by grouping predictions according to model, difficulty, context length, and evidence position. For each group, we compute total samples, number of correct predictions, and exact-match accuracy. This enables detailed analysis of positional bias, including primacy and recency effects, as well as performance degradation in mid-context regions.
#
# This setup ensures that all models are evaluated on identical inputs under consistent conditions, allowing observed differences in performance to be attributed to model capacity rather than variations in data or prompting.

# %%
"""
Run positional-bias evaluation across multiple Ollama models.
"""

from __future__ import annotations

import json
import re
import time
from pathlib import Path
from typing import Any

import pandas as pd
import requests


DATASET_PATH = Path("positional_bias_dataset.jsonl")
RESULTS_PATH = Path("positional_bias_results.jsonl")
SUMMARY_PATH = Path("positional_bias_summary.csv")

OLLAMA_GENERATE_URL = "http://localhost:11434/api/generate"

MODELS = [
    "tinyllama",
    "llama3.2:1b",
    "llama3.2:3b",
]

REQUEST_TIMEOUT_SECONDS = 600
SLEEP_BETWEEN_REQUESTS = 0.2
MAX_SAMPLES: int | None = None


def load_jsonl(path: Path) -> list[dict[str, Any]]:
    """Load dataset rows from JSONL as dictionaries."""
    with path.open("r", encoding="utf-8") as file:
        return [json.loads(line) for line in file]


def append_jsonl(row: dict[str, Any], path: Path) -> None:
    """Append one result row to a JSONL output file."""
    with path.open("a", encoding="utf-8") as file:
        file.write(json.dumps(row, ensure_ascii=False) + "\n")


def extract_first_five_digit_code(text: str) -> str | None:
    """Extract the first five-digit number from model output."""
    match = re.search(r"\b\d{5}\b", text)
    return match.group(0) if match else None


def build_eval_prompt(original_prompt: str) -> str:
    """Wrap the original prompt with stricter output rules."""
    return f"""{original_prompt}

STRICT OUTPUT RULE:
Return exactly one five-digit number.
Do not return words, punctuation, explanation, or markdown.
"""


def query_ollama(model: str, prompt: str) -> str:
    """Run one Ollama model call."""
    payload = {
        "model": model,
        "prompt": build_eval_prompt(prompt),
        "stream": False,
        "options": {
            "temperature": 0,
            "top_p": 1,
            "num_predict": 32,
        },
    }

    response = requests.post(
        OLLAMA_GENERATE_URL,
        json=payload,
        timeout=REQUEST_TIMEOUT_SECONDS,
    )
    response.raise_for_status()

    return response.json().get("response", "").strip()


def run_experiment() -> None:
    """Run all samples through all selected models."""
    dataset = load_jsonl(DATASET_PATH)

    if MAX_SAMPLES is not None:
        dataset = dataset[:MAX_SAMPLES]

    if RESULTS_PATH.exists():
        RESULTS_PATH.unlink()

    total_runs = len(dataset) * len(MODELS)
    run_counter = 0

    print(f"Loaded {len(dataset)} samples")
    print(f"Models: {MODELS}")
    print(f"Total runs: {total_runs}")
    print(f"Writing results to: {RESULTS_PATH}")

    for model in MODELS:
        print(f"\n=== Running model: {model} ===")

        for sample in dataset:
            run_counter += 1
            gold_answer = sample["gold_answer"]

            try:
                raw_response = query_ollama(model, sample["prompt"])
                predicted_answer = extract_first_five_digit_code(raw_response)
                is_correct = predicted_answer == gold_answer
                error = None

            except Exception as exc:
                raw_response = ""
                predicted_answer = None
                is_correct = False
                error = repr(exc)

            result = {
                "sample_id": sample["sample_id"],
                "model": model,
                "difficulty": sample.get("difficulty"),
                "context_length": sample["context_length"],
                "num_distractors": sample["num_distractors"],
                "evidence_position": sample["evidence_position"],
                "target_project": sample["target_project"],
                "gold_answer": gold_answer,
                "predicted_answer": predicted_answer,
                "raw_response": raw_response,
                "is_correct": is_correct,
                "error": error,
            }

            append_jsonl(result, RESULTS_PATH)

            print(
                f"[{run_counter}/{total_runs}] "
                f"model={model} | "
                f"id={sample['sample_id']} | "
                f"difficulty={sample.get('difficulty')} | "
                f"context={sample['context_length']} | "
                f"position={sample['evidence_position']} | "
                f"gold={gold_answer} | "
                f"pred={predicted_answer} | "
                f"correct={is_correct}"
            )

            if predicted_answer is None:
                print(f"  raw_response={repr(raw_response[:300])}")
                print(f"  error={error}")

            time.sleep(SLEEP_BETWEEN_REQUESTS)

    create_summary()


def create_summary() -> None:
    """Summarise accuracy by model, difficulty, context length, and position."""
    df = pd.DataFrame(load_jsonl(RESULTS_PATH))

    summary = (
        df.groupby(["model", "difficulty", "context_length", "evidence_position"])
        .agg(
            total_samples=("sample_id", "count"),
            correct=("is_correct", "sum"),
            accuracy=("is_correct", "mean"),
            failed_requests=("error", lambda x: x.notna().sum()),
        )
        .reset_index()
        .sort_values(["model", "difficulty", "context_length", "evidence_position"])
    )

    summary.to_csv(SUMMARY_PATH, index=False)

    print("\nAccuracy summary:")
    print(summary)
    print(f"\nSaved summary to: {SUMMARY_PATH}")


if __name__ == "__main__":
    run_experiment()
# Out:
# Loaded 540 samples
# Models: ['tinyllama', 'llama3.2:1b', 'llama3.2:3b']
# Total runs: 1620
# Writing results to: positional_bias_results.jsonl
#
# === Running model: tinyllama ===
# [1/1620] model=tinyllama | id=124 | difficulty=easy | context=long | position=beginning | gold=76694 | pred=12345 | correct=False
# [2/1620] model=tinyllama | id=52 | difficulty=easy | context=short | position=end | gold=76247 | pred=76247 | correct=True
# [3/1620] model=tinyllama | id=56 | difficulty=easy | context=short | position=end | gold=19661 | pred=19661 | correct=True
# [4/1620] model=tinyllama | id=519 | difficulty=hard | context=long | position=middle | gold=24157 | pred=52621 | correct=False
# [5/1620] model=tinyllama | id=421 | difficulty=hard | context=medium | position=beginning | gold=68138 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Vega".'
#   error=None
# [6/1620] model=tinyllama | id=103 | difficulty=easy | context=medium | position=end | gold=23226 | pred=23226 | correct=True
# [7/1620] model=tinyllama | id=218 | difficulty=medium | context=short | position=middle | gold=52738 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora-Prime.'
#   error=None
# [8/1620] model=tinyllama | id=79 | difficulty=easy | context=medium | position=beginning | gold=51229 | pred=51229 | correct=True
# [9/1620] model=tinyllama | id=258 | difficulty=medium | context=medium | position=beginning | gold=90626 | pred=90626 | correct=True
# [10/1620] model=tinyllama | id=353 | difficulty=medium | context=long | position=end | gold=87317 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Orion-Prime, you can follow these steps:\n\n1. Identify the project name and its identifier'
#   error=None
# [11/1620] model=tinyllama | id=327 | difficulty=medium | context=long | position=middle | gold=92835 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega using the given text, follow these steps:\n\n1. Identify the first occurrence of a "V'
#   error=None
# [12/1620] model=tinyllama | id=301 | difficulty=medium | context=long | position=beginning | gold=14876 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora, you can use the following steps:\n\n1. Identify the server pin for Project Aurora ('
#   error=None
# [13/1620] model=tinyllama | id=428 | difficulty=hard | context=medium | position=beginning | gold=62262 | pred=52752 | correct=False
# [14/1620] model=tinyllama | id=328 | difficulty=medium | context=long | position=middle | gold=75542 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora-Primé, you can follow these steps:\n\n1. Locate the archive key for Project Ly'
#   error=None
# [15/1620] model=tinyllama | id=381 | difficulty=hard | context=short | position=middle | gold=68111 | pred=35817 | correct=False
# [16/1620] model=tinyllama | id=12 | difficulty=easy | context=short | position=beginning | gold=24953 | pred=24953 | correct=True
# [17/1620] model=tinyllama | id=442 | difficulty=hard | context=medium | position=middle | gold=24127 | pred=83246 | correct=False
# [18/1620] model=tinyllama | id=457 | difficulty=hard | context=medium | position=middle | gold=52261 | pred=92096 | correct=False
# [19/1620] model=tinyllama | id=35 | difficulty=easy | context=short | position=middle | gold=10895 | pred=42435 | correct=False
# [20/1620] model=tinyllama | id=239 | difficulty=medium | context=short | position=end | gold=41629 | pred=57815 | correct=False
# [21/1620] model=tinyllama | id=225 | difficulty=medium | context=short | position=end | gold=69580 | pred=69580 | correct=True
# [22/1620] model=tinyllama | id=228 | difficulty=medium | context=short | position=end | gold=63118 | pred=85479 | correct=False
# [23/1620] model=tinyllama | id=379 | difficulty=hard | context=short | position=beginning | gold=16956 | pred=16956 | correct=True
# [24/1620] model=tinyllama | id=431 | difficulty=hard | context=medium | position=beginning | gold=55260 | pred=14673 | correct=False
# [25/1620] model=tinyllama | id=483 | difficulty=hard | context=long | position=beginning | gold=89563 | pred=16776 | correct=False
# [26/1620] model=tinyllama | id=520 | difficulty=hard | context=long | position=end | gold=10321 | pred=10321 | correct=True
# [27/1620] model=tinyllama | id=294 | difficulty=medium | context=medium | position=end | gold=75923 | pred=75923 | correct=True
# [28/1620] model=tinyllama | id=108 | difficulty=easy | context=medium | position=end | gold=61543 | pred=61543 | correct=True
# [29/1620] model=tinyllama | id=446 | difficulty=hard | context=medium | position=middle | gold=39229 | pred=39354 | correct=False
# [30/1620] model=tinyllama | id=159 | difficulty=easy | context=long | position=middle | gold=38342 | pred=12345 | correct=False
# [31/1620] model=tinyllama | id=198 | difficulty=medium | context=short | position=beginning | gold=44640 | pred=45550 | correct=False
# [32/1620] model=tinyllama | id=288 | difficulty=medium | context=medium | position=end | gold=39261 | pred=44858 | correct=False
# [33/1620] model=tinyllama | id=398 | difficulty=hard | context=short | position=middle | gold=80742 | pred=71521 | correct=False
# [34/1620] model=tinyllama | id=140 | difficulty=easy | context=long | position=middle | gold=78319 | pred=12345 | correct=False
# [35/1620] model=tinyllama | id=443 | difficulty=hard | context=medium | position=middle | gold=76350 | pred=18100 | correct=False
# [36/1620] model=tinyllama | id=451 | difficulty=hard | context=medium | position=middle | gold=97808 | pred=32470 | correct=False
# [37/1620] model=tinyllama | id=452 | difficulty=hard | context=medium | position=middle | gold=54458 | pred=12840 | correct=False
# [38/1620] model=tinyllama | id=364 | difficulty=hard | context=short | position=beginning | gold=61558 | pred=61558 | correct=True
# [39/1620] model=tinyllama | id=271 | difficulty=medium | context=medium | position=middle | gold=62270 | pred=17050 | correct=False
# [40/1620] model=tinyllama | id=323 | difficulty=medium | context=long | position=middle | gold=98428 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora-Prime, follow these steps:\n\n1. Locate the archive key for Project Aurora-'
#   error=None
# [41/1620] model=tinyllama | id=404 | difficulty=hard | context=short | position=end | gold=84538 | pred=34348 | correct=False
# [42/1620] model=tinyllama | id=201 | difficulty=medium | context=short | position=middle | gold=97612 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Orion-Prime.'
#   error=None
# [43/1620] model=tinyllama | id=481 | difficulty=hard | context=long | position=beginning | gold=19801 | pred=71263 | correct=False
# [44/1620] model=tinyllama | id=377 | difficulty=hard | context=short | position=beginning | gold=49927 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Orion".'
#   error=None
# [45/1620] model=tinyllama | id=195 | difficulty=medium | context=short | position=beginning | gold=80391 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Vega.'
#   error=None
# [46/1620] model=tinyllama | id=41 | difficulty=easy | context=short | position=end | gold=19634 | pred=19634 | correct=True
# [47/1620] model=tinyllama | id=72 | difficulty=easy | context=medium | position=beginning | gold=11999 | pred=11999 | correct=True
# [48/1620] model=tinyllama | id=60 | difficulty=easy | context=medium | position=beginning | gold=50037 | pred=50037 | correct=True
# [49/1620] model=tinyllama | id=307 | difficulty=medium | context=long | position=beginning | gold=17217 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the archive key for Project VegaX (8'
#   error=None
# [50/1620] model=tinyllama | id=456 | difficulty=hard | context=medium | position=middle | gold=72345 | pred=15827 | correct=False
# [51/1620] model=tinyllama | id=1 | difficulty=easy | context=short | position=beginning | gold=44993 | pred=44993 | correct=True
# [52/1620] model=tinyllama | id=212 | difficulty=medium | context=short | position=middle | gold=66626 | pred=81120 | correct=False
# [53/1620] model=tinyllama | id=180 | difficulty=medium | context=short | position=beginning | gold=24213 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Lyra-Prime.'
#   error=None
# [54/1620] model=tinyllama | id=410 | difficulty=hard | context=short | position=end | gold=63118 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Orion".'
#   error=None
# [55/1620] model=tinyllama | id=98 | difficulty=easy | context=medium | position=middle | gold=69768 | pred=69768 | correct=True
# [56/1620] model=tinyllama | id=427 | difficulty=hard | context=medium | position=beginning | gold=95768 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Lyra".'
#   error=None
# [57/1620] model=tinyllama | id=75 | difficulty=easy | context=medium | position=beginning | gold=15975 | pred=15975 | correct=True
# [58/1620] model=tinyllama | id=468 | difficulty=hard | context=medium | position=end | gold=83772 | pred=78238 | correct=False
# [59/1620] model=tinyllama | id=136 | difficulty=easy | context=long | position=beginning | gold=95462 | pred=12345 | correct=False
# [60/1620] model=tinyllama | id=219 | difficulty=medium | context=short | position=middle | gold=80581 | pred=53960 | correct=False
# [61/1620] model=tinyllama | id=512 | difficulty=hard | context=long | position=middle | gold=59728 | pred=36599 | correct=False
# [62/1620] model=tinyllama | id=252 | difficulty=medium | context=medium | position=beginning | gold=79732 | pred=79732 | correct=True
# [63/1620] model=tinyllama | id=516 | difficulty=hard | context=long | position=middle | gold=89034 | pred=12345 | correct=False
# [64/1620] model=tinyllama | id=49 | difficulty=easy | context=short | position=end | gold=94694 | pred=94694 | correct=True
# [65/1620] model=tinyllama | id=135 | difficulty=easy | context=long | position=beginning | gold=71890 | pred=12345 | correct=False
# [66/1620] model=tinyllama | id=158 | difficulty=easy | context=long | position=middle | gold=70924 | pred=12345 | correct=False
# [67/1620] model=tinyllama | id=200 | difficulty=medium | context=short | position=middle | gold=72044 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project OrionX.'
#   error=None
# [68/1620] model=tinyllama | id=285 | difficulty=medium | context=medium | position=end | gold=17793 | pred=17793 | correct=True
# [69/1620] model=tinyllama | id=96 | difficulty=easy | context=medium | position=middle | gold=40161 | pred=86148 | correct=False
# [70/1620] model=tinyllama | id=125 | difficulty=easy | context=long | position=beginning | gold=21170 | pred=12345 | correct=False
# [71/1620] model=tinyllama | id=146 | difficulty=easy | context=long | position=middle | gold=66084 | pred=12345 | correct=False
# [72/1620] model=tinyllama | id=25 | difficulty=easy | context=short | position=middle | gold=84766 | pred=67340 | correct=False
# [73/1620] model=tinyllama | id=306 | difficulty=medium | context=long | position=beginning | gold=94558 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Orion-Prime, you can follow these steps:\n\n1. Locate the archive key for Project Ori'
#   error=None
# [74/1620] model=tinyllama | id=68 | difficulty=easy | context=medium | position=beginning | gold=76316 | pred=76316 | correct=True
# [75/1620] model=tinyllama | id=318 | difficulty=medium | context=long | position=beginning | gold=65098 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project LyraX, follow these steps:\n\n1. Locate the archive key for Project LyraX (9'
#   error=None
# [76/1620] model=tinyllama | id=497 | difficulty=hard | context=long | position=beginning | gold=44913 | pred=12345 | correct=False
# [77/1620] model=tinyllama | id=281 | difficulty=medium | context=medium | position=end | gold=21583 | pred=21583 | correct=True
# [78/1620] model=tinyllama | id=325 | difficulty=medium | context=long | position=middle | gold=86863 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega, you can use the following SQL query:\n\n```sql\nSELECT DISTINCT id FROM project_'
#   error=None
# [79/1620] model=tinyllama | id=277 | difficulty=medium | context=medium | position=middle | gold=24801 | pred=None | correct=False
#   raw_response='The context provides the answer to the question "Find the identifier code assigned to Project Aurora-Prime." The final number returned is the identifier code for Project'
#   error=None
# [80/1620] model=tinyllama | id=77 | difficulty=easy | context=medium | position=beginning | gold=85199 | pred=85199 | correct=True
# [81/1620] model=tinyllama | id=450 | difficulty=hard | context=medium | position=middle | gold=72864 | pred=91249 | correct=False
# [82/1620] model=tinyllama | id=489 | difficulty=hard | context=long | position=beginning | gold=63002 | pred=12345 | correct=False
# [83/1620] model=tinyllama | id=189 | difficulty=medium | context=short | position=beginning | gold=79942 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Lyra.'
#   error=None
# [84/1620] model=tinyllama | id=453 | difficulty=hard | context=medium | position=middle | gold=61484 | pred=13282 | correct=False
# [85/1620] model=tinyllama | id=303 | difficulty=medium | context=long | position=beginning | gold=56829 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra-Prime, follow these steps:\n\n1. Locate the archive key for Project Lyra-'
#   error=None
# [86/1620] model=tinyllama | id=476 | difficulty=hard | context=medium | position=end | gold=25091 | pred=25091 | correct=True
# [87/1620] model=tinyllama | id=416 | difficulty=hard | context=short | position=end | gold=17875 | pred=38053 | correct=False
# [88/1620] model=tinyllama | id=322 | difficulty=medium | context=long | position=middle | gold=44329 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project OrionX, you can follow these steps:\n\n1. Identify the archive key for Project OrionX'
#   error=None
# [89/1620] model=tinyllama | id=22 | difficulty=easy | context=short | position=middle | gold=97562 | pred=40968 | correct=False
# [90/1620] model=tinyllama | id=214 | difficulty=medium | context=short | position=middle | gold=49620 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora.'
#   error=None
# [91/1620] model=tinyllama | id=418 | difficulty=hard | context=short | position=end | gold=99339 | pred=12110 | correct=False
# [92/1620] model=tinyllama | id=373 | difficulty=hard | context=short | position=beginning | gold=20484 | pred=20484 | correct=True
# [93/1620] model=tinyllama | id=399 | difficulty=hard | context=short | position=middle | gold=74513 | pred=13823 | correct=False
# [94/1620] model=tinyllama | id=85 | difficulty=easy | context=medium | position=middle | gold=86812 | pred=86812 | correct=True
# [95/1620] model=tinyllama | id=137 | difficulty=easy | context=long | position=beginning | gold=28611 | pred=12345 | correct=False
# [96/1620] model=tinyllama | id=111 | difficulty=easy | context=medium | position=end | gold=71260 | pred=71260 | correct=True
# [97/1620] model=tinyllama | id=342 | difficulty=medium | context=long | position=end | gold=68432 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega, you can follow these steps:\n\n1. Identify the project name: "Project Vega"'
#   error=None
# [98/1620] model=tinyllama | id=528 | difficulty=hard | context=long | position=end | gold=50060 | pred=13647 | correct=False
# [99/1620] model=tinyllama | id=89 | difficulty=easy | context=medium | position=middle | gold=99123 | pred=38910 | correct=False
# [100/1620] model=tinyllama | id=317 | difficulty=medium | context=long | position=beginning | gold=42660 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra, follow these steps:\n\n1. Locate the text "Project Lyra" in the given text'
#   error=None
# [101/1620] model=tinyllama | id=298 | difficulty=medium | context=medium | position=end | gold=96874 | pred=96874 | correct=True
# [102/1620] model=tinyllama | id=216 | difficulty=medium | context=short | position=middle | gold=42896 | pred=38579 | correct=False
# [103/1620] model=tinyllama | id=117 | difficulty=easy | context=medium | position=end | gold=55657 | pred=55657 | correct=True
# [104/1620] model=tinyllama | id=93 | difficulty=easy | context=medium | position=middle | gold=45044 | pred=45044 | correct=True
# [105/1620] model=tinyllama | id=449 | difficulty=hard | context=medium | position=middle | gold=92956 | pred=39684 | correct=False
# [106/1620] model=tinyllama | id=97 | difficulty=easy | context=medium | position=middle | gold=91719 | pred=91719 | correct=True
# [107/1620] model=tinyllama | id=321 | difficulty=medium | context=long | position=middle | gold=83075 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project OrionX, you can follow these steps:\n\n1. Identify the project name: "Project Orion'
#   error=None
# [108/1620] model=tinyllama | id=539 | difficulty=hard | context=long | position=end | gold=10238 | pred=10238 | correct=True
# [109/1620] model=tinyllama | id=86 | difficulty=easy | context=medium | position=middle | gold=39573 | pred=39573 | correct=True
# [110/1620] model=tinyllama | id=170 | difficulty=easy | context=long | position=end | gold=21865 | pred=21865 | correct=True
# [111/1620] model=tinyllama | id=400 | difficulty=hard | context=short | position=end | gold=10887 | pred=50161 | correct=False
# [112/1620] model=tinyllama | id=454 | difficulty=hard | context=medium | position=middle | gold=45381 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Vega".'
#   error=None
# [113/1620] model=tinyllama | id=240 | difficulty=medium | context=medium | position=beginning | gold=41393 | pred=41393 | correct=True
# [114/1620] model=tinyllama | id=352 | difficulty=medium | context=long | position=end | gold=98649 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the "identifier code" field in the given text'
#   error=None
# [115/1620] model=tinyllama | id=78 | difficulty=easy | context=medium | position=beginning | gold=54832 | pred=54832 | correct=True
# [116/1620] model=tinyllama | id=475 | difficulty=hard | context=medium | position=end | gold=28978 | pred=32617 | correct=False
# [117/1620] model=tinyllama | id=437 | difficulty=hard | context=medium | position=beginning | gold=33183 | pred=38785 | correct=False
# [118/1620] model=tinyllama | id=339 | difficulty=medium | context=long | position=middle | gold=17944 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega-Prime, follow these steps:\n\n1. Locate the archive key for Project LyraX'
#   error=None
# [119/1620] model=tinyllama | id=197 | difficulty=medium | context=short | position=beginning | gold=20724 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project LyraX.'
#   error=None
# [120/1620] model=tinyllama | id=13 | difficulty=easy | context=short | position=beginning | gold=17816 | pred=17816 | correct=True
# [121/1620] model=tinyllama | id=237 | difficulty=medium | context=short | position=end | gold=67673 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Lyra.'
#   error=None
# [122/1620] model=tinyllama | id=241 | difficulty=medium | context=medium | position=beginning | gold=74400 | pred=74400 | correct=True
# [123/1620] model=tinyllama | id=467 | difficulty=hard | context=medium | position=end | gold=51592 | pred=57127 | correct=False
# [124/1620] model=tinyllama | id=287 | difficulty=medium | context=medium | position=end | gold=51754 | pred=51754 | correct=True
# [125/1620] model=tinyllama | id=361 | difficulty=hard | context=short | position=beginning | gold=87854 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Lyra-Prime".'
#   error=None
# [126/1620] model=tinyllama | id=347 | difficulty=medium | context=long | position=end | gold=63483 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega-Prime, you can follow these steps:\n\n1. Identify the project name and its identifier'
#   error=None
# [127/1620] model=tinyllama | id=179 | difficulty=easy | context=long | position=end | gold=80487 | pred=80487 | correct=True
# [128/1620] model=tinyllama | id=254 | difficulty=medium | context=medium | position=beginning | gold=87226 | pred=87226 | correct=True
# [129/1620] model=tinyllama | id=249 | difficulty=medium | context=medium | position=beginning | gold=45359 | pred=82588 | correct=False
# [130/1620] model=tinyllama | id=162 | difficulty=easy | context=long | position=end | gold=38001 | pred=38001 | correct=True
# [131/1620] model=tinyllama | id=267 | difficulty=medium | context=medium | position=middle | gold=17941 | pred=93242 | correct=False
# [132/1620] model=tinyllama | id=132 | difficulty=easy | context=long | position=beginning | gold=43189 | pred=53999 | correct=False
# [133/1620] model=tinyllama | id=193 | difficulty=medium | context=short | position=beginning | gold=12116 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project AuroraX.'
#   error=None
# [134/1620] model=tinyllama | id=530 | difficulty=hard | context=long | position=end | gold=41782 | pred=13984 | correct=False
# [135/1620] model=tinyllama | id=87 | difficulty=easy | context=medium | position=middle | gold=28931 | pred=28931 | correct=True
# [136/1620] model=tinyllama | id=139 | difficulty=easy | context=long | position=beginning | gold=81509 | pred=12345 | correct=False
# [137/1620] model=tinyllama | id=286 | difficulty=medium | context=medium | position=end | gold=85122 | pred=85122 | correct=True
# [138/1620] model=tinyllama | id=208 | difficulty=medium | context=short | position=middle | gold=26385 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Orion.'
#   error=None
# [139/1620] model=tinyllama | id=88 | difficulty=easy | context=medium | position=middle | gold=69183 | pred=69183 | correct=True
# [140/1620] model=tinyllama | id=105 | difficulty=easy | context=medium | position=end | gold=63729 | pred=63729 | correct=True
# [141/1620] model=tinyllama | id=380 | difficulty=hard | context=short | position=middle | gold=69258 | pred=14392 | correct=False
# [142/1620] model=tinyllama | id=284 | difficulty=medium | context=medium | position=end | gold=43647 | pred=47652 | correct=False
# [143/1620] model=tinyllama | id=233 | difficulty=medium | context=short | position=end | gold=21613 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora.'
#   error=None
# [144/1620] model=tinyllama | id=255 | difficulty=medium | context=medium | position=beginning | gold=72841 | pred=72841 | correct=True
# [145/1620] model=tinyllama | id=417 | difficulty=hard | context=short | position=end | gold=66279 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Lyra".'
#   error=None
# [146/1620] model=tinyllama | id=266 | difficulty=medium | context=medium | position=middle | gold=17370 | pred=16512 | correct=False
# [147/1620] model=tinyllama | id=168 | difficulty=easy | context=long | position=end | gold=52549 | pred=52549 | correct=True
# [148/1620] model=tinyllama | id=11 | difficulty=easy | context=short | position=beginning | gold=74332 | pred=74332 | correct=True
# [149/1620] model=tinyllama | id=167 | difficulty=easy | context=long | position=end | gold=41957 | pred=41957 | correct=True
# [150/1620] model=tinyllama | id=480 | difficulty=hard | context=long | position=beginning | gold=60632 | pred=18813 | correct=False
# [151/1620] model=tinyllama | id=246 | difficulty=medium | context=medium | position=beginning | gold=40343 | pred=40343 | correct=True
# [152/1620] model=tinyllama | id=345 | difficulty=medium | context=long | position=end | gold=54812 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra, you can follow these steps:\n\n1. Start by identifying the project name "Lyra'
#   error=None
# [153/1620] model=tinyllama | id=110 | difficulty=easy | context=medium | position=end | gold=26874 | pred=26874 | correct=True
# [154/1620] model=tinyllama | id=477 | difficulty=hard | context=medium | position=end | gold=43386 | pred=16742 | correct=False
# [155/1620] model=tinyllama | id=21 | difficulty=easy | context=short | position=middle | gold=69460 | pred=79066 | correct=False
# [156/1620] model=tinyllama | id=227 | difficulty=medium | context=short | position=end | gold=29499 | pred=29499 | correct=True
# [157/1620] model=tinyllama | id=415 | difficulty=hard | context=short | position=end | gold=25246 | pred=30573 | correct=False
# [158/1620] model=tinyllama | id=104 | difficulty=easy | context=medium | position=end | gold=60146 | pred=60146 | correct=True
# [159/1620] model=tinyllama | id=46 | difficulty=easy | context=short | position=end | gold=68947 | pred=68947 | correct=True
# [160/1620] model=tinyllama | id=84 | difficulty=easy | context=medium | position=middle | gold=77692 | pred=77692 | correct=True
# [161/1620] model=tinyllama | id=172 | difficulty=easy | context=long | position=end | gold=99284 | pred=None | correct=False
#   raw_response='The correct output rule for this prompt is:\n\nReturn exactly one five-digit number. Do not return words, punctuation, explanation, or mark'
#   error=None
# [162/1620] model=tinyllama | id=383 | difficulty=hard | context=short | position=middle | gold=12956 | pred=12956 | correct=True
# [163/1620] model=tinyllama | id=50 | difficulty=easy | context=short | position=end | gold=25202 | pred=64559 | correct=False
# [164/1620] model=tinyllama | id=71 | difficulty=easy | context=medium | position=beginning | gold=87983 | pred=87983 | correct=True
# [165/1620] model=tinyllama | id=369 | difficulty=hard | context=short | position=beginning | gold=51984 | pred=51984 | correct=True
# [166/1620] model=tinyllama | id=402 | difficulty=hard | context=short | position=end | gold=77518 | pred=35843 | correct=False
# [167/1620] model=tinyllama | id=134 | difficulty=easy | context=long | position=beginning | gold=43393 | pred=97616 | correct=False
# [168/1620] model=tinyllama | id=360 | difficulty=hard | context=short | position=beginning | gold=89288 | pred=80872 | correct=False
# [169/1620] model=tinyllama | id=366 | difficulty=hard | context=short | position=beginning | gold=82735 | pred=82735 | correct=True
# [170/1620] model=tinyllama | id=69 | difficulty=easy | context=medium | position=beginning | gold=72371 | pred=72371 | correct=True
# [171/1620] model=tinyllama | id=462 | difficulty=hard | context=medium | position=end | gold=98612 | pred=98612 | correct=True
# [172/1620] model=tinyllama | id=509 | difficulty=hard | context=long | position=middle | gold=87333 | pred=15660 | correct=False
# [173/1620] model=tinyllama | id=279 | difficulty=medium | context=medium | position=middle | gold=13691 | pred=13691 | correct=True
# [174/1620] model=tinyllama | id=488 | difficulty=hard | context=long | position=beginning | gold=33668 | pred=12345 | correct=False
# [175/1620] model=tinyllama | id=112 | difficulty=easy | context=medium | position=end | gold=49943 | pred=49943 | correct=True
# [176/1620] model=tinyllama | id=523 | difficulty=hard | context=long | position=end | gold=56215 | pred=54179 | correct=False
# [177/1620] model=tinyllama | id=101 | difficulty=easy | context=medium | position=end | gold=42029 | pred=42029 | correct=True
# [178/1620] model=tinyllama | id=444 | difficulty=hard | context=medium | position=middle | gold=61904 | pred=15292 | correct=False
# [179/1620] model=tinyllama | id=30 | difficulty=easy | context=short | position=middle | gold=13718 | pred=17852 | correct=False
# [180/1620] model=tinyllama | id=20 | difficulty=easy | context=short | position=middle | gold=59060 | pred=86869 | correct=False
# [181/1620] model=tinyllama | id=24 | difficulty=easy | context=short | position=middle | gold=96057 | pred=53694 | correct=False
# [182/1620] model=tinyllama | id=316 | difficulty=medium | context=long | position=beginning | gold=97911 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora-Prime, follow these steps:\n\n1. Locate the archive key for Project Aurora-'
#   error=None
# [183/1620] model=tinyllama | id=82 | difficulty=easy | context=medium | position=middle | gold=83801 | pred=83801 | correct=True
# [184/1620] model=tinyllama | id=268 | difficulty=medium | context=medium | position=middle | gold=33303 | pred=57131 | correct=False
# [185/1620] model=tinyllama | id=333 | difficulty=medium | context=long | position=middle | gold=45953 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Orion-Prime, you can follow these steps:\n\n1. Locate the archive key for Project Ori'
#   error=None
# [186/1620] model=tinyllama | id=529 | difficulty=hard | context=long | position=end | gold=90425 | pred=13514 | correct=False
# [187/1620] model=tinyllama | id=220 | difficulty=medium | context=short | position=end | gold=99394 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora.'
#   error=None
# [188/1620] model=tinyllama | id=74 | difficulty=easy | context=medium | position=beginning | gold=18906 | pred=18906 | correct=True
# [189/1620] model=tinyllama | id=203 | difficulty=medium | context=short | position=middle | gold=44733 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Vega-Prime.'
#   error=None
# [190/1620] model=tinyllama | id=181 | difficulty=medium | context=short | position=beginning | gold=95531 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora-Prime.'
#   error=None
# [191/1620] model=tinyllama | id=486 | difficulty=hard | context=long | position=beginning | gold=27099 | pred=12345 | correct=False
# [192/1620] model=tinyllama | id=408 | difficulty=hard | context=short | position=end | gold=37563 | pred=13092 | correct=False
# [193/1620] model=tinyllama | id=348 | difficulty=medium | context=long | position=end | gold=49439 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the archive key for Project VegaX (which'
#   error=None
# [194/1620] model=tinyllama | id=365 | difficulty=hard | context=short | position=beginning | gold=17289 | pred=17289 | correct=True
# [195/1620] model=tinyllama | id=207 | difficulty=medium | context=short | position=middle | gold=48368 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora.'
#   error=None
# [196/1620] model=tinyllama | id=368 | difficulty=hard | context=short | position=beginning | gold=65581 | pred=65800 | correct=False
# [197/1620] model=tinyllama | id=490 | difficulty=hard | context=long | position=beginning | gold=72110 | pred=12345 | correct=False
# [198/1620] model=tinyllama | id=312 | difficulty=medium | context=long | position=beginning | gold=37134 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the archive key for Project VegaX (which'
#   error=None
# [199/1620] model=tinyllama | id=535 | difficulty=hard | context=long | position=end | gold=38870 | pred=32120 | correct=False
# [200/1620] model=tinyllama | id=330 | difficulty=medium | context=long | position=middle | gold=56093 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra-Prime, you can follow these steps:\n\n1. Identify the archive key for Project Ly'
#   error=None
# [201/1620] model=tinyllama | id=389 | difficulty=hard | context=short | position=middle | gold=71816 | pred=87881 | correct=False
# [202/1620] model=tinyllama | id=521 | difficulty=hard | context=long | position=end | gold=87784 | pred=12345 | correct=False
# [203/1620] model=tinyllama | id=113 | difficulty=easy | context=medium | position=end | gold=53741 | pred=53741 | correct=True
# [204/1620] model=tinyllama | id=81 | difficulty=easy | context=medium | position=middle | gold=88654 | pred=88654 | correct=True
# [205/1620] model=tinyllama | id=95 | difficulty=easy | context=medium | position=middle | gold=81994 | pred=81994 | correct=True
# [206/1620] model=tinyllama | id=295 | difficulty=medium | context=medium | position=end | gold=15256 | pred=15256 | correct=True
# [207/1620] model=tinyllama | id=175 | difficulty=easy | context=long | position=end | gold=89783 | pred=89783 | correct=True
# [208/1620] model=tinyllama | id=48 | difficulty=easy | context=short | position=end | gold=78084 | pred=78084 | correct=True
# [209/1620] model=tinyllama | id=107 | difficulty=easy | context=medium | position=end | gold=75147 | pred=75147 | correct=True
# [210/1620] model=tinyllama | id=458 | difficulty=hard | context=medium | position=middle | gold=43848 | pred=86336 | correct=False
# [211/1620] model=tinyllama | id=423 | difficulty=hard | context=medium | position=beginning | gold=32598 | pred=32598 | correct=True
# [212/1620] model=tinyllama | id=182 | difficulty=medium | context=short | position=beginning | gold=36513 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project LyraX.'
#   error=None
# [213/1620] model=tinyllama | id=533 | difficulty=hard | context=long | position=end | gold=42973 | pred=12345 | correct=False
# [214/1620] model=tinyllama | id=314 | difficulty=medium | context=long | position=beginning | gold=45830 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra-Prime, follow these steps:\n\n1. Locate the archive key for Project Lyra-'
#   error=None
# [215/1620] model=tinyllama | id=184 | difficulty=medium | context=short | position=beginning | gold=94513 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project LyraX.'
#   error=None
# [216/1620] model=tinyllama | id=165 | difficulty=easy | context=long | position=end | gold=19588 | pred=19588 | correct=True
# [217/1620] model=tinyllama | id=33 | difficulty=easy | context=short | position=middle | gold=35200 | pred=47649 | correct=False
# [218/1620] model=tinyllama | id=396 | difficulty=hard | context=short | position=middle | gold=92069 | pred=92501 | correct=False
# [219/1620] model=tinyllama | id=411 | difficulty=hard | context=short | position=end | gold=25994 | pred=54861 | correct=False
# [220/1620] model=tinyllama | id=406 | difficulty=hard | context=short | position=end | gold=74323 | pred=74323 | correct=True
# [221/1620] model=tinyllama | id=273 | difficulty=medium | context=medium | position=middle | gold=32482 | pred=32482 | correct=True
# [222/1620] model=tinyllama | id=43 | difficulty=easy | context=short | position=end | gold=80040 | pred=80040 | correct=True
# [223/1620] model=tinyllama | id=504 | difficulty=hard | context=long | position=middle | gold=21719 | pred=14938 | correct=False
# [224/1620] model=tinyllama | id=10 | difficulty=easy | context=short | position=beginning | gold=49529 | pred=49529 | correct=True
# [225/1620] model=tinyllama | id=40 | difficulty=easy | context=short | position=end | gold=72390 | pred=72390 | correct=True
# [226/1620] model=tinyllama | id=302 | difficulty=medium | context=long | position=beginning | gold=78047 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora, follow these steps:\n\n1. Locate the archive key for Project Aurora (465'
#   error=None
# [227/1620] model=tinyllama | id=482 | difficulty=hard | context=long | position=beginning | gold=96000 | pred=19380 | correct=False
# [228/1620] model=tinyllama | id=234 | difficulty=medium | context=short | position=end | gold=74457 | pred=74457 | correct=True
# [229/1620] model=tinyllama | id=407 | difficulty=hard | context=short | position=end | gold=58501 | pred=53358 | correct=False
# [230/1620] model=tinyllama | id=374 | difficulty=hard | context=short | position=beginning | gold=18649 | pred=18649 | correct=True
# [231/1620] model=tinyllama | id=47 | difficulty=easy | context=short | position=end | gold=10324 | pred=10324 | correct=True
# [232/1620] model=tinyllama | id=275 | difficulty=medium | context=medium | position=middle | gold=91559 | pred=72371 | correct=False
# [233/1620] model=tinyllama | id=447 | difficulty=hard | context=medium | position=middle | gold=90340 | pred=31250 | correct=False
# [234/1620] model=tinyllama | id=278 | difficulty=medium | context=medium | position=middle | gold=41307 | pred=39004 | correct=False
# [235/1620] model=tinyllama | id=350 | difficulty=medium | context=long | position=end | gold=66920 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project AuroraX, follow these steps:\n\n1. Locate the archive key for Project AuroraX (which'
#   error=None
# [236/1620] model=tinyllama | id=243 | difficulty=medium | context=medium | position=beginning | gold=60440 | pred=60440 | correct=True
# [237/1620] model=tinyllama | id=232 | difficulty=medium | context=short | position=end | gold=96467 | pred=96467 | correct=True
# [238/1620] model=tinyllama | id=346 | difficulty=medium | context=long | position=end | gold=60616 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the archive key for Project VegaX (6'
#   error=None
# [239/1620] model=tinyllama | id=183 | difficulty=medium | context=short | position=beginning | gold=55962 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Aurora-Prime.'
#   error=None
# [240/1620] model=tinyllama | id=192 | difficulty=medium | context=short | position=beginning | gold=56450 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Vega-Prime.'
#   error=None
# [241/1620] model=tinyllama | id=121 | difficulty=easy | context=long | position=beginning | gold=47324 | pred=12345 | correct=False
# [242/1620] model=tinyllama | id=59 | difficulty=easy | context=short | position=end | gold=76426 | pred=76426 | correct=True
# [243/1620] model=tinyllama | id=341 | difficulty=medium | context=long | position=end | gold=81538 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Lyra-Prime, follow these steps:\n\n1. Locate the archive key for Project Lyra-'
#   error=None
# [244/1620] model=tinyllama | id=235 | difficulty=medium | context=short | position=end | gold=62149 | pred=62149 | correct=True
# [245/1620] model=tinyllama | id=291 | difficulty=medium | context=medium | position=end | gold=59470 | pred=59470 | correct=True
# [246/1620] model=tinyllama | id=27 | difficulty=easy | context=short | position=middle | gold=69988 | pred=14081 | correct=False
# [247/1620] model=tinyllama | id=430 | difficulty=hard | context=medium | position=beginning | gold=18313 | pred=18313 | correct=True
# [248/1620] model=tinyllama | id=174 | difficulty=easy | context=long | position=end | gold=89130 | pred=89130 | correct=True
# [249/1620] model=tinyllama | id=525 | difficulty=hard | context=long | position=end | gold=21907 | pred=36649 | correct=False
# [250/1620] model=tinyllama | id=147 | difficulty=easy | context=long | position=middle | gold=57626 | pred=18242 | correct=False
# [251/1620] model=tinyllama | id=231 | difficulty=medium | context=short | position=end | gold=15780 | pred=None | correct=False
#   raw_response='The final number returned by the context is the identifier code assigned to Project Lyra.'
#   error=None
# [252/1620] model=tinyllama | id=334 | difficulty=medium | context=long | position=middle | gold=28677 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project OrionX, you can follow these steps:\n\n1. Identify the archive key for Project OrionX'
#   error=None
# [253/1620] model=tinyllama | id=261 | difficulty=medium | context=medium | position=middle | gold=96000 | pred=74036 | correct=False
# [254/1620] model=tinyllama | id=357 | difficulty=medium | context=long | position=end | gold=64391 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora, you can follow these steps:\n\n1. Identify the first digit of the identifier code assigned to'
#   error=None
# [255/1620] model=tinyllama | id=332 | difficulty=medium | context=long | position=middle | gold=66682 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project AuroraX, you can use the following steps:\n\n1. Identify the server pin for Project Aurora'
#   error=None
# [256/1620] model=tinyllama | id=70 | difficulty=easy | context=medium | position=beginning | gold=45887 | pred=45887 | correct=True
# [257/1620] model=tinyllama | id=459 | difficulty=hard | context=medium | position=middle | gold=86178 | pred=53345 | correct=False
# [258/1620] model=tinyllama | id=120 | difficulty=easy | context=long | position=beginning | gold=55066 | pred=12345 | correct=False
# [259/1620] model=tinyllama | id=413 | difficulty=hard | context=short | position=end | gold=64894 | pred=63549 | correct=False
# [260/1620] model=tinyllama | id=441 | difficulty=hard | context=medium | position=middle | gold=91481 | pred=53211 | correct=False
# [261/1620] model=tinyllama | id=358 | difficulty=medium | context=long | position=end | gold=68830 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Aurora, you can follow these steps:\n\n1. Identify the archive key for Project Aurora (9'
#   error=None
# [262/1620] model=tinyllama | id=412 | difficulty=hard | context=short | position=end | gold=58165 | pred=None | correct=False
#   raw_response='The answer to the question is "Project VegaX" as it is the identifier code associated with Project VegaX.'
#   error=None
# [263/1620] model=tinyllama | id=14 | difficulty=easy | context=short | position=beginning | gold=16764 | pred=16764 | correct=True
# [264/1620] model=tinyllama | id=340 | difficulty=medium | context=long | position=end | gold=54753 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project VegaX, follow these steps:\n\n1. Locate the archive key for Project VegaX (which'
#   error=None
# [265/1620] model=tinyllama | id=129 | difficulty=easy | context=long | position=beginning | gold=83112 | pred=12345 | correct=False
# [266/1620] model=tinyllama | id=395 | difficulty=hard | context=short | position=middle | gold=90674 | pred=73983 | correct=False
# [267/1620] model=tinyllama | id=259 | difficulty=medium | context=medium | position=beginning | gold=62246 | pred=62246 | correct=True
# [268/1620] model=tinyllama | id=61 | difficulty=easy | context=medium | position=beginning | gold=16322 | pred=16322 | correct=True
# [269/1620] model=tinyllama | id=305 | difficulty=medium | context=long | position=beginning | gold=18678 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Orion-Prime, you can follow these steps:\n\n1. Locate the archive key for Project Ori'
#   error=None
# [270/1620] model=tinyllama | id=536 | difficulty=hard | context=long | position=end | gold=68832 | pred=13671 | correct=False
# [271/1620] model=tinyllama | id=238 | difficulty=medium | context=short | position=end | gold=18810 | pred=18810 | correct=True
# [272/1620] model=tinyllama | id=370 | difficulty=hard | context=short | position=beginning | gold=22212 | pred=10945 | correct=False
# [273/1620] model=tinyllama | id=515 | difficulty=hard | context=long | position=middle | gold=36312 | pred=19531 | correct=False
# [274/1620] model=tinyllama | id=16 | difficulty=easy | context=short | position=beginning | gold=91226 | pred=91226 | correct=True
# [275/1620] model=tinyllama | id=385 | difficulty=hard | context=short | position=middle | gold=16868 | pred=None | correct=False
#   raw_response='The answer to the question is "Project Orion".'
#   error=None
# [276/1620] model=tinyllama | id=176 | difficulty=easy | context=long | position=end | gold=99591 | pred=99591 | correct=True
# [277/1620] model=tinyllama | id=23 | difficulty=easy | context=short | position=middle | gold=29786 | pred=52143 | correct=False
# [278/1620] model=tinyllama | id=409 | difficulty=hard | context=short | position=end | gold=56965 | pred=61732 | correct=False
# [279/1620] model=tinyllama | id=166 | difficulty=easy | context=long | position=end | gold=35952 | pred=35952 | correct=True
# [280/1620] model=tinyllama | id=310 | difficulty=medium | context=long | position=beginning | gold=97693 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project Vega-Prime, follow these steps:\n\n1. Locate the text "Project Vega-Prim'
#   error=None
# [281/1620] model=tinyllama | id=173 | difficulty=easy | context=long | position=end | gold=32604 | pred=32604 | correct=True
# [282/1620] model=tinyllama | id=461 | difficulty=hard | context=medium | position=end | gold=65587 | pred=68935 | correct=False
# [283/1620] model=tinyllama | id=44 | difficulty=easy | context=short | position=end | gold=41970 | pred=82339 | correct=False
# [284/1620] model=tinyllama | id=304 | difficulty=medium | context=long | position=beginning | gold=56991 | pred=None | correct=False
#   raw_response='To find the identifier code assigned to Project AuroraX, follow these steps:\n\n1. Locate the archive key for Project AuroraX (which'
#   error=None
# [285/1620] model=tinyllama | id=276 | difficulty=medium | context=medium | position=middle | gold=55521 | pred=76406 | correct=False
# [286/1620] model=tinyllama | id=492 | difficulty=hard | context=long | position=beginning | gold=74164 | pred=30481 | correct=False
# [287/1620] model=tinyllama | id=150 | difficulty=easy | context=long | position=middle | gold=92862 | pred=23513 | correct=False
# [288/1620] model=tinyllama | id=32 | difficulty=easy | context=short | position=middle | gold=77568 | pred=77568 | correct=True
# [289/1620] model=tinyllama | id=299 | difficulty=medium | context=medium | position=end | gold=53153 | pred=53153 | correct=True
# [290/1620] model=tinyllama | id=63 | difficulty=easy | context=medium | position=beginning | gold=94182 | pred=94182 | correct=True
# [291/1620] model=tinyllama | id=138 | difficulty=easy | context=long | position=beginning | gold=42017 | pred=12345 | correct=False
# [292/1620] model=tinyllama | id=114 | difficulty=easy | context=medium | position=end | gold=23224 | pred=23224 | correct=True
# [293/1620] model=tinyllama | id=229 | difficulty=medium | context=short | position=end | gold=72659 | pred=72659 | correct=True
# [294/1620] model=tinyllama | id=391 | difficulty=hard | context=short | position=middle | gold=69905 | pred=39998 | correct=False
# [295/1620] model=tinyllama | id=296 | difficulty=medium | context=medium | position=end | gold=75970 | pred=75970 | correct=True
# ...
# [1512/1620] model=llama3.2:3b | id=18 | difficulty=easy | context=short | position=beginning | gold=30253 | pred=30253 | correct=True
# [1513/1620] model=llama3.2:3b | id=505 | difficulty=hard | context=long | position=middle | gold=73282 | pred=85016 | correct=False
# [1514/1620] model=llama3.2:3b | id=463 | difficulty=hard | context=medium | position=end | gold=19876 | pred=79004 | correct=False
# [1515/1620] model=llama3.2:3b | id=31 | difficulty=easy | context=short | position=middle | gold=75308 | pred=75308 | correct=True
# [1516/1620] model=llama3.2:3b | id=280 | difficulty=medium | context=medium | position=end | gold=12760 | pred=12760 | correct=True
# [1517/1620] model=llama3.2:3b | id=434 | difficulty=hard | context=medium | position=beginning | gold=28662 | pred=28662 | correct=True
# [1518/1620] model=llama3.2:3b | id=57 | difficulty=easy | context=short | position=end | gold=44734 | pred=44734 | correct=True
# [1519/1620] model=llama3.2:3b | id=282 | difficulty=medium | context=medium | position=end | gold=72834 | pred=72834 | correct=True
# [1520/1620] model=llama3.2:3b | id=145 | difficulty=easy | context=long | position=middle | gold=11453 | pred=11453 | correct=True
# [1521/1620] model=llama3.2:3b | id=36 | difficulty=easy | context=short | position=middle | gold=21919 | pred=21919 | correct=True
# [1522/1620] model=llama3.2:3b | id=265 | difficulty=medium | context=medium | position=middle | gold=19693 | pred=19693 | correct=True
# [1523/1620] model=llama3.2:3b | id=251 | difficulty=medium | context=medium | position=beginning | gold=63937 | pred=63937 | correct=True
# [1524/1620] model=llama3.2:3b | id=445 | difficulty=hard | context=medium | position=middle | gold=81688 | pred=81688 | correct=True
# [1525/1620] model=llama3.2:3b | id=177 | difficulty=easy | context=long | position=end | gold=74591 | pred=74591 | correct=True
# [1526/1620] model=llama3.2:3b | id=371 | difficulty=hard | context=short | position=beginning | gold=91184 | pred=88949 | correct=False
# [1527/1620] model=llama3.2:3b | id=106 | difficulty=easy | context=medium | position=end | gold=35647 | pred=35647 | correct=True
# [1528/1620] model=llama3.2:3b | id=65 | difficulty=easy | context=medium | position=beginning | gold=20986 | pred=20986 | correct=True
# [1529/1620] model=llama3.2:3b | id=163 | difficulty=easy | context=long | position=end | gold=10042 | pred=10042 | correct=True
# [1530/1620] model=llama3.2:3b | id=39 | difficulty=easy | context=short | position=middle | gold=56160 | pred=56160 | correct=True
# [1531/1620] model=llama3.2:3b | id=55 | difficulty=easy | context=short | position=end | gold=27884 | pred=27884 | correct=True
# [1532/1620] model=llama3.2:3b | id=390 | difficulty=hard | context=short | position=middle | gold=90810 | pred=90810 | correct=True
# [1533/1620] model=llama3.2:3b | id=236 | difficulty=medium | context=short | position=end | gold=70788 | pred=70788 | correct=True
# [1534/1620] model=llama3.2:3b | id=440 | difficulty=hard | context=medium | position=middle | gold=94556 | pred=94556 | correct=True
# [1535/1620] model=llama3.2:3b | id=354 | difficulty=medium | context=long | position=end | gold=76119 | pred=76119 | correct=True
# [1536/1620] model=llama3.2:3b | id=83 | difficulty=easy | context=medium | position=middle | gold=96108 | pred=96108 | correct=True
# [1537/1620] model=llama3.2:3b | id=466 | difficulty=hard | context=medium | position=end | gold=16861 | pred=53666 | correct=False
# [1538/1620] model=llama3.2:3b | id=115 | difficulty=easy | context=medium | position=end | gold=29034 | pred=29034 | correct=True
# [1539/1620] model=llama3.2:3b | id=487 | difficulty=hard | context=long | position=beginning | gold=44139 | pred=47718 | correct=False
# [1540/1620] model=llama3.2:3b | id=424 | difficulty=hard | context=medium | position=beginning | gold=17005 | pred=85251 | correct=False
# [1541/1620] model=llama3.2:3b | id=426 | difficulty=hard | context=medium | position=beginning | gold=35167 | pred=96618 | correct=False
# [1542/1620] model=llama3.2:3b | id=290 | difficulty=medium | context=medium | position=end | gold=26888 | pred=26888 | correct=True
# [1543/1620] model=llama3.2:3b | id=94 | difficulty=easy | context=medium | position=middle | gold=90951 | pred=90951 | correct=True
# [1544/1620] model=llama3.2:3b | id=92 | difficulty=easy | context=medium | position=middle | gold=59200 | pred=59200 | correct=True
# [1545/1620] model=llama3.2:3b | id=344 | difficulty=medium | context=long | position=end | gold=29565 | pred=29565 | correct=True
# [1546/1620] model=llama3.2:3b | id=319 | difficulty=medium | context=long | position=beginning | gold=75772 | pred=75772 | correct=True
# [1547/1620] model=llama3.2:3b | id=67 | difficulty=easy | context=medium | position=beginning | gold=27865 | pred=27865 | correct=True
# [1548/1620] model=llama3.2:3b | id=471 | difficulty=hard | context=medium | position=end | gold=71354 | pred=75630 | correct=False
# [1549/1620] model=llama3.2:3b | id=154 | difficulty=easy | context=long | position=middle | gold=18372 | pred=18372 | correct=True
# [1550/1620] model=llama3.2:3b | id=64 | difficulty=easy | context=medium | position=beginning | gold=92132 | pred=92132 | correct=True
# [1551/1620] model=llama3.2:3b | id=485 | difficulty=hard | context=long | position=beginning | gold=11380 | pred=37713 | correct=False
# [1552/1620] model=llama3.2:3b | id=537 | difficulty=hard | context=long | position=end | gold=23825 | pred=87066 | correct=False
# [1553/1620] model=llama3.2:3b | id=309 | difficulty=medium | context=long | position=beginning | gold=74119 | pred=74119 | correct=True
# [1554/1620] model=llama3.2:3b | id=76 | difficulty=easy | context=medium | position=beginning | gold=49955 | pred=49955 | correct=True
# [1555/1620] model=llama3.2:3b | id=464 | difficulty=hard | context=medium | position=end | gold=87700 | pred=19807 | correct=False
# [1556/1620] model=llama3.2:3b | id=336 | difficulty=medium | context=long | position=middle | gold=31543 | pred=31543 | correct=True
# [1557/1620] model=llama3.2:3b | id=439 | difficulty=hard | context=medium | position=beginning | gold=16093 | pred=54726 | correct=False
# [1558/1620] model=llama3.2:3b | id=141 | difficulty=easy | context=long | position=middle | gold=49423 | pred=49423 | correct=True
# [1559/1620] model=llama3.2:3b | id=127 | difficulty=easy | context=long | position=beginning | gold=86820 | pred=86820 | correct=True
# [1560/1620] model=llama3.2:3b | id=313 | difficulty=medium | context=long | position=beginning | gold=52879 | pred=52879 | correct=True
# [1561/1620] model=llama3.2:3b | id=51 | difficulty=easy | context=short | position=end | gold=51934 | pred=51934 | correct=True
# [1562/1620] model=llama3.2:3b | id=230 | difficulty=medium | context=short | position=end | gold=35764 | pred=35764 | correct=True
# [1563/1620] model=llama3.2:3b | id=331 | difficulty=medium | context=long | position=middle | gold=95333 | pred=95333 | correct=True
# [1564/1620] model=llama3.2:3b | id=217 | difficulty=medium | context=short | position=middle | gold=50509 | pred=50509 | correct=True
# [1565/1620] model=llama3.2:3b | id=401 | difficulty=hard | context=short | position=end | gold=22978 | pred=74610 | correct=False
# [1566/1620] model=llama3.2:3b | id=513 | difficulty=hard | context=long | position=middle | gold=21904 | pred=23144 | correct=False
# [1567/1620] model=llama3.2:3b | id=362 | difficulty=hard | context=short | position=beginning | gold=49352 | pred=49352 | correct=True
# [1568/1620] model=llama3.2:3b | id=131 | difficulty=easy | context=long | position=beginning | gold=61393 | pred=61393 | correct=True
# [1569/1620] model=llama3.2:3b | id=194 | difficulty=medium | context=short | position=beginning | gold=36860 | pred=36860 | correct=True
# [1570/1620] model=llama3.2:3b | id=38 | difficulty=easy | context=short | position=middle | gold=49418 | pred=49418 | correct=True
# [1571/1620] model=llama3.2:3b | id=80 | difficulty=easy | context=medium | position=middle | gold=33066 | pred=33066 | correct=True
# [1572/1620] model=llama3.2:3b | id=386 | difficulty=hard | context=short | position=middle | gold=58735 | pred=58735 | correct=True
# [1573/1620] model=llama3.2:3b | id=382 | difficulty=hard | context=short | position=middle | gold=31783 | pred=31783 | correct=True
# [1574/1620] model=llama3.2:3b | id=335 | difficulty=medium | context=long | position=middle | gold=86115 | pred=86115 | correct=True
# [1575/1620] model=llama3.2:3b | id=4 | difficulty=easy | context=short | position=beginning | gold=69638 | pred=69638 | correct=True
# [1576/1620] model=llama3.2:3b | id=326 | difficulty=medium | context=long | position=middle | gold=41720 | pred=41720 | correct=True
# [1577/1620] model=llama3.2:3b | id=151 | difficulty=easy | context=long | position=middle | gold=77108 | pred=77108 | correct=True
# [1578/1620] model=llama3.2:3b | id=320 | difficulty=medium | context=long | position=middle | gold=25335 | pred=25335 | correct=True
# [1579/1620] model=llama3.2:3b | id=122 | difficulty=easy | context=long | position=beginning | gold=54979 | pred=54979 | correct=True
# [1580/1620] model=llama3.2:3b | id=90 | difficulty=easy | context=medium | position=middle | gold=64502 | pred=64502 | correct=True
# [1581/1620] model=llama3.2:3b | id=205 | difficulty=medium | context=short | position=middle | gold=54069 | pred=54069 | correct=True
# [1582/1620] model=llama3.2:3b | id=355 | difficulty=medium | context=long | position=end | gold=35835 | pred=35835 | correct=True
# [1583/1620] model=llama3.2:3b | id=469 | difficulty=hard | context=medium | position=end | gold=93612 | pred=76688 | correct=False
# [1584/1620] model=llama3.2:3b | id=297 | difficulty=medium | context=medium | position=end | gold=88286 | pred=88286 | correct=True
# [1585/1620] model=llama3.2:3b | id=152 | difficulty=easy | context=long | position=middle | gold=95981 | pred=95981 | correct=True
# [1586/1620] model=llama3.2:3b | id=405 | difficulty=hard | context=short | position=end | gold=25246 | pred=97138 | correct=False
# [1587/1620] model=llama3.2:3b | id=397 | difficulty=hard | context=short | position=middle | gold=58167 | pred=58167 | correct=True
# [1588/1620] model=llama3.2:3b | id=54 | difficulty=easy | context=short | position=end | gold=17679 | pred=17679 | correct=True
# [1589/1620] model=llama3.2:3b | id=384 | difficulty=hard | context=short | position=middle | gold=22960 | pred=22960 | correct=True
# [1590/1620] model=llama3.2:3b | id=324 | difficulty=medium | context=long | position=middle | gold=82306 | pred=82306 | correct=True
# [1591/1620] model=llama3.2:3b | id=270 | difficulty=medium | context=medium | position=middle | gold=79560 | pred=79560 | correct=True
# [1592/1620] model=llama3.2:3b | id=532 | difficulty=hard | context=long | position=end | gold=41326 | pred=41326 | correct=True
# [1593/1620] model=llama3.2:3b | id=495 | difficulty=hard | context=long | position=beginning | gold=54266 | pred=26108 | correct=False
# [1594/1620] model=llama3.2:3b | id=213 | difficulty=medium | context=short | position=middle | gold=93088 | pred=93088 | correct=True
# [1595/1620] model=llama3.2:3b | id=343 | difficulty=medium | context=long | position=end | gold=68025 | pred=68025 | correct=True
# [1596/1620] model=llama3.2:3b | id=514 | difficulty=hard | context=long | position=middle | gold=20453 | pred=47179 | correct=False
# [1597/1620] model=llama3.2:3b | id=148 | difficulty=easy | context=long | position=middle | gold=38984 | pred=38984 | correct=True
# [1598/1620] model=llama3.2:3b | id=470 | difficulty=hard | context=medium | position=end | gold=21812 | pred=29006 | correct=False
# [1599/1620] model=llama3.2:3b | id=429 | difficulty=hard | context=medium | position=beginning | gold=70017 | pred=29919 | correct=False
# [1600/1620] model=llama3.2:3b | id=308 | difficulty=medium | context=long | position=beginning | gold=46371 | pred=46371 | correct=True
# [1601/1620] model=llama3.2:3b | id=19 | difficulty=easy | context=short | position=beginning | gold=44782 | pred=44782 | correct=True
# [1602/1620] model=llama3.2:3b | id=247 | difficulty=medium | context=medium | position=beginning | gold=44562 | pred=44562 | correct=True
# [1603/1620] model=llama3.2:3b | id=153 | difficulty=easy | context=long | position=middle | gold=39582 | pred=39582 | correct=True
# [1604/1620] model=llama3.2:3b | id=149 | difficulty=easy | context=long | position=middle | gold=56369 | pred=56369 | correct=True
# [1605/1620] model=llama3.2:3b | id=178 | difficulty=easy | context=long | position=end | gold=88643 | pred=88643 | correct=True
# [1606/1620] model=llama3.2:3b | id=502 | difficulty=hard | context=long | position=middle | gold=73488 | pred=68812 | correct=False
# [1607/1620] model=llama3.2:3b | id=123 | difficulty=easy | context=long | position=beginning | gold=82575 | pred=82575 | correct=True
# [1608/1620] model=llama3.2:3b | id=263 | difficulty=medium | context=medium | position=middle | gold=57390 | pred=57390 | correct=True
# [1609/1620] model=llama3.2:3b | id=100 | difficulty=easy | context=medium | position=end | gold=20852 | pred=20852 | correct=True
# [1610/1620] model=llama3.2:3b | id=510 | difficulty=hard | context=long | position=middle | gold=85139 | pred=85139 | correct=True
# [1611/1620] model=llama3.2:3b | id=157 | difficulty=easy | context=long | position=middle | gold=72768 | pred=72768 | correct=True
# [1612/1620] model=llama3.2:3b | id=392 | difficulty=hard | context=short | position=middle | gold=80703 | pred=80703 | correct=True
# [1613/1620] model=llama3.2:3b | id=253 | difficulty=medium | context=medium | position=beginning | gold=30532 | pred=30532 | correct=True
# [1614/1620] model=llama3.2:3b | id=289 | difficulty=medium | context=medium | position=end | gold=11868 | pred=11868 | correct=True
# [1615/1620] model=llama3.2:3b | id=503 | difficulty=hard | context=long | position=middle | gold=40158 | pred=83200 | correct=False
# [1616/1620] model=llama3.2:3b | id=126 | difficulty=easy | context=long | position=beginning | gold=35905 | pred=35905 | correct=True
# [1617/1620] model=llama3.2:3b | id=224 | difficulty=medium | context=short | position=end | gold=49173 | pred=49173 | correct=True
# [1618/1620] model=llama3.2:3b | id=272 | difficulty=medium | context=medium | position=middle | gold=55698 | pred=55698 | correct=True
# [1619/1620] model=llama3.2:3b | id=337 | difficulty=medium | context=long | position=middle | gold=83450 | pred=83450 | correct=True
# [1620/1620] model=llama3.2:3b | id=508 | difficulty=hard | context=long | position=middle | gold=33689 | pred=26119 | correct=False
#
# Accuracy summary:
#           model difficulty context_length evidence_position  total_samples  \
# 0   llama3.2:1b       easy           long         beginning             20
# 1   llama3.2:1b       easy           long               end             20
# 2   llama3.2:1b       easy           long            middle             20
# 3   llama3.2:1b       easy         medium         beginning             20
# 4   llama3.2:1b       easy         medium               end             20
# ..          ...        ...            ...               ...            ...
# 76    tinyllama     medium         medium               end             20
# 77    tinyllama     medium         medium            middle             20
# 78    tinyllama     medium          short         beginning             20
# 79    tinyllama     medium          short               end             20
# 80    tinyllama     medium          short            middle             20
#
#     correct  accuracy  failed_requests
# 0        20      1.00                0
# 1        15      0.75                0
# 2        19      0.95                0
# 3        18      0.90                0
# 4        16      0.80                0
# ..      ...       ...              ...
# 76       17      0.85                0
# 77        2      0.10                0
# 78        1      0.05                0
# 79       10      0.50                0
# 80        0      0.00                0
#
# [81 rows x 8 columns]
#
# Saved summary to: positional_bias_summary.csv

# %% [markdown]
# ## Visual Comparison
#
# To analyse positional bias across models and experimental conditions, we perform a structured visual comparison of model performance using aggregated accuracy metrics. Visualisation serves as the primary tool for identifying systematic trends such as **primacy effects**, **recency effects**, and **degradation in middle-context retrieval**.
#
# All plots are generated from the aggregated results file, which contains exact-match accuracy computed for each combination of model, difficulty level, context length, and evidence position. Categorical variables are explicitly ordered to ensure consistent comparisons, with models arranged by increasing capacity (TinyLlama, LLaMA 3.2 1B, LLaMA 3.2 3B) and evidence positions ordered as Beginning, Middle, and End.
#
# ### Positional Bias Plots
#
# The primary visualisation consists of **scatter plots** showing accuracy as a function of evidence position. Separate plots are generated for each context length condition (short, medium, long), with each model represented by a distinct marker and accuracy computed as the mean exact-match score.
#
# To improve readability, a small amount of horizontal jitter and transparency (alpha) are applied to points. No connecting lines are used, as evidence position is categorical, and legends are placed outside the plot area to avoid occlusion. These plots enable direct comparison of positional performance across models and context lengths.
#
# ### Difficulty-Specific Analysis
#
# To isolate the effect of task complexity, the analysis is repeated using only samples from the **hard difficulty setting**, which introduces confusable project names, semantically similar distractor keys, and same-project distractors. This allows assessment of how positional bias interacts with task difficulty and whether model robustness degrades under more complex conditions.
#
# ### Edge vs Middle Comparison
#
# To quantify the **“lost-in-the-middle” effect**, beginning and end positions are collapsed into an **Edge** category and compared against the **Middle** position. Accuracy is aggregated using total correct predictions and total samples, and results are visualised using bar charts for each context length. This provides a simplified and interpretable comparison of boundary versus mid-context performance.
#
# ### Interpretation Strategy
#
# The visual comparison framework supports three key analyses:
#
# - **Positional bias detection**, by identifying U-shaped accuracy patterns (Beginning ≈ End > Middle)
# - **Model capacity effects**, by comparing performance across models of increasing size
# - **Context-length interaction**, by examining whether positional bias becomes more pronounced as context length increases
#
# By combining scatter plots, difficulty-specific analysis, and edge-versus-middle comparisons, this methodology provides a comprehensive and interpretable framework for analysing positional bias in LLMs under controlled conditions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# -----------------------------
# Load data
# -----------------------------

INPUT_CSV = "positional_bias_summary.csv"
OUTPUT_DIR = Path("figures")
OUTPUT_DIR.mkdir(exist_ok=True)

df = pd.read_csv(INPUT_CSV)

position_order = ["beginning", "middle", "end"]
context_order = ["short", "medium", "long"]
difficulty_order = ["easy", "medium", "hard"]
model_order = MODELS

df["model"] = pd.Categorical(
    df["model"],
    categories=model_order,
    ordered=True,
)

df["evidence_position"] = pd.Categorical(
    df["evidence_position"], categories=position_order, ordered=True
)
df["context_length"] = pd.Categorical(
    df["context_length"], categories=context_order, ordered=True
)
df["difficulty"] = pd.Categorical(
    df["difficulty"], categories=difficulty_order, ordered=True
)

position_to_x = {"beginning": 0, "middle": 1, "end": 2}
markers = ["o", "s", "D", "^", "v"]

# -----------------------------
# Plot style helper
# -----------------------------

def apply_publication_style(title: str) -> None:
    plt.title(title, fontsize=13, weight="bold")
    plt.xlabel("Evidence Position", fontsize=11)
    plt.ylabel("Exact-Match Accuracy", fontsize=11)
    plt.xticks([0, 1, 2], ["Beginning", "Middle", "End"])
    plt.ylim(-0.02, 1.05)
    plt.grid(axis="y", alpha=0.3)

    # Legend outside
    plt.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        frameon=False,
        fontsize=9,
        borderaxespad=0,
    )

    plt.tight_layout(rect=[0, 0, 0.8, 1])


# -----------------------------
# Scatter plot
# -----------------------------

def plot_position_scatter(data: pd.DataFrame, title: str, output_path: Path) -> None:
    plt.figure(figsize=(7.2, 4.2))

    for idx, model in enumerate(model_order):
        if model not in data["model"].astype(str).unique():
            continue
        model_data = (
            data[data["model"] == model]
            .groupby("evidence_position", observed=True)["accuracy"]
            .mean()
            .reset_index()
            .sort_values("evidence_position")
        )

        model_data["x"] = model_data["evidence_position"].astype(str).map(position_to_x)

        jitter = (np.random.rand(len(model_data)) - 0.5) * 0.05

        plt.scatter(
            model_data["x"] + jitter,
            model_data["accuracy"],
            s=90,
            marker=markers[idx % len(markers) + 1],
            label=model,
            alpha=0.5,
            edgecolors="black",
            linewidths=0.5,
            zorder=3,
        )

    apply_publication_style(title)
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()


# -----------------------------
# Figure 1
# -----------------------------

for context in df["context_length"].dropna().unique():
    subset_context = df[df["context_length"] == context]

    plot_position_scatter(
        data=subset_context,
        title=f"Positional Bias Across Models ({str(context).capitalize()} Context)",
        output_path=OUTPUT_DIR / f"scatter_positional_bias_{context}.png",
    )


# -----------------------------
# Figure 2
# -----------------------------

df_hard = df[df["difficulty"] == "hard"]

for context in df_hard["context_length"].dropna().unique():
    subset_context = df_hard[df_hard["context_length"] == context]

    plot_position_scatter(
        data=subset_context,
        title=f"Positional Bias on Hard Samples ({str(context).capitalize()} Context)",
        output_path=OUTPUT_DIR / f"scatter_positional_bias_hard_{context}.png",
    )


# -----------------------------
# Figure 3
# -----------------------------

df_edge = df.copy()
df_edge["position_group"] = df_edge["evidence_position"].apply(
    lambda x: "Middle" if x == "middle" else "Edge"
)

middle_edge_summary = (
    df_edge
    .groupby(["model", "context_length", "position_group"], observed=True)["accuracy"]
    .mean()
    .reset_index()
)

for context in middle_edge_summary["context_length"].dropna().unique():
    subset = middle_edge_summary[
        middle_edge_summary["context_length"] == context
    ]

    pivot = subset.pivot(
        index="model",
        columns="position_group",
        values="accuracy",
    )

    plt.figure(figsize=(7.5, 4.2))
    pivot.plot(kind="bar", ax=plt.gca(), width=0.75)

    plt.title(
        f"Middle vs Edge Retrieval Accuracy ({str(context).capitalize()} Context)",
        fontsize=13,
        weight="bold",
    )
    plt.xlabel("Model", fontsize=11)
    plt.ylabel("Exact-Match Accuracy", fontsize=11)
    plt.ylim(-0.02, 1.05)
    plt.xticks(rotation=20, ha="right")
    plt.grid(axis="y", alpha=0.3)

    # Legend outside
    plt.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        frameon=False,
        fontsize=9,
    )

    plt.tight_layout(rect=[0, 0, 0.8, 1])

    output_path = OUTPUT_DIR / f"middle_vs_edge_{context}.png"
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()

# %%
import json
import math
from collections import defaultdict

def calculate_stats(file_path, num_folds=5):
    data = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(list))))
    
    with open(file_path, 'r') as f:
        for line in f:
            entry = json.loads(line)
            model = entry['model']
            diff = entry['difficulty']
            length = entry['context_length']
            pos = entry['evidence_position']
            # Treat errors or null as incorrect
            is_correct = entry.get('is_correct', False)
            if is_correct is None: is_correct = False
            data[model][diff][length][pos].append(int(is_correct))

    results = {}
    for model in data:
        results[model] = {}
        for diff in data[model]:
            results[model][diff] = {}
            for length in data[model][diff]:
                results[model][diff][length] = {}
                for pos in data[model][diff][length]:
                    samples = data[model][diff][length][pos]
                    # Split into folds
                    fold_size = len(samples) // num_folds
                    fold_accuracies = []
                    for i in range(num_folds):
                        fold = samples[i*fold_size : (i+1)*fold_size]
                        acc = sum(fold) / len(fold)
                        fold_accuracies.append(acc)
                    
                    mean = sum(fold_accuracies) / len(fold_accuracies)
                    variance = sum((x - mean) ** 2 for x in fold_accuracies) / len(fold_accuracies)
                    std = math.sqrt(variance)
                    
                    results[model][diff][length][pos] = {
                        "mean": round(mean, 2),
                        "std": round(std, 2)
                    }
    return results

if __name__ == "__main__":
    stats = calculate_stats('target/Assignment/positional_bias_results.jsonl')
    with open('analysis/data/stats.json', 'w') as f:
        json.dump(stats, f, indent=2)
    print("Stats calculated and saved to analysis/data/stats.json")
# Out:
# Stats calculated and saved to stats.json
